# %% [markdown]
# Importing

# %%
import numpy as np
import pandas as pd

# %%
# Loading the Data from the CSV file
air_quality_data = pd.read_csv('/content/AQI-and-Lat-Long-of-Countries.csv')

# %%
# Printing the first 5 rows of the Dataframe
air_quality_data.head()
# Out:
#    AQI Value  CO AQI Value  Ozone AQI Value  NO2 AQI Value  PM2.5 AQI Value  \
# 0         51             1               36              0               51
# 1         41             1                5              1               41
# 2         41             1                5              1               41
# 3         66             1               39              2               66
# 4         34             1               34              0               20
#
#        lat      lng
# 0  44.7444  44.2031
# 1  -5.2900 -44.4900
# 2 -11.2958 -41.9869
# 3  37.1667  15.1833
# 4  53.0167  20.8833
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['AQI Value'].plot(kind='hist', bins=20, title='AQI Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['Ozone AQI Value'].plot(kind='hist', bins=20, title='Ozone AQI Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['NO2 AQI Value'].plot(kind='hist', bins=20, title='NO2 AQI Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['PM2.5 AQI Value'].plot(kind='hist', bins=20, title='PM2.5 AQI Value')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='AQI Value', y='Ozone AQI Value', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='Ozone AQI Value', y='NO2 AQI Value', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='NO2 AQI Value', y='PM2.5 AQI Value', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='PM2.5 AQI Value', y='lat', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CO AQI Value']
#   ys = series['AQI Value']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('CO AQI Value', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CO AQI Value')
# _ = plt.ylabel('AQI Value')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CO AQI Value']
#   ys = series['Ozone AQI Value']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('CO AQI Value', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CO AQI Value')
# _ = plt.ylabel('Ozone AQI Value')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CO AQI Value']
#   ys = series['NO2 AQI Value']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('CO AQI Value', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CO AQI Value')
# _ = plt.ylabel('NO2 AQI Value')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['CO AQI Value']
#   ys = series['PM2.5 AQI Value']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('CO AQI Value', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('CO AQI Value')
# _ = plt.ylabel('PM2.5 AQI Value')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['AQI Value'].plot(kind='line', figsize=(8, 4), title='AQI Value')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['Ozone AQI Value'].plot(kind='line', figsize=(8, 4), title='Ozone AQI Value')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['NO2 AQI Value'].plot(kind='line', figsize=(8, 4), title='NO2 AQI Value')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['PM2.5 AQI Value'].plot(kind='line', figsize=(8, 4), title='PM2.5 AQI Value')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
air_quality_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Data columns (total 7 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   AQI Value        16695 non-null  int64
#  1   CO AQI Value     16695 non-null  int64
#  2   Ozone AQI Value  16695 non-null  int64
#  3   NO2 AQI Value    16695 non-null  int64
#  4   PM2.5 AQI Value  16695 non-null  int64
#  5   lat              16695 non-null  float64
#  6   lng              16695 non-null  float64
# dtypes: float64(2), int64(5)
# memory usage: 913.1 KB

# %%
from sklearn.ensemble import RandomForestRegressor, AdaBoostRegressor

# %%
#CREATING MODEL
m1= RandomForestRegressor()


train1= air_quality_data.drop(['AQI Value'], axis=1)

target= air_quality_data['AQI Value']

print(train1)
print(target)
# Out:
#        CO AQI Value  Ozone AQI Value  NO2 AQI Value  PM2.5 AQI Value      lat  \
# 0                 1               36              0               51  44.7444
# 1                 1                5              1               41  -5.2900
# 2                 1                5              1               41 -11.2958
# 3                 1               39              2               66  37.1667
# 4                 1               34              0               20  53.0167
# ...             ...              ...            ...              ...      ...
# 16690             1               34              5               54  37.5516
# 16691             1               39              1               71  49.0650
# 16692             1               39              1               71  36.3385
# 16693             1               20              5               50  48.7786
# 16694             1               44              2               71  40.1241
#
#            lng
# 0      44.2031
# 1     -44.4900
# 2     -41.9869
# 3      15.1833
# 4      20.8833
# ...        ...
# 16690 -77.3285
# 16691  18.9219
# 16692 -88.8513
# 16693   2.2906
# 16694 -82.9210
#
# [16695 rows x 6 columns]
# 0        51
# 1        41
# 2        41
# 3        66
# 4        34
#          ..
# 16690    54
# 16691    71
# 16692    71
# 16693    50
# 16694    71
# Name: AQI Value, Length: 16695, dtype: int64

# %%
#FITTING THE MODEL
m1.fit(train1, target)

m1.score(train1, target)*100

# predicting the model with other values (testing the data)
prediction_result= m1.predict([[1, 10, 5, 11, 10, 5]])

print(prediction_result)
# Out:
# [9.95]
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(

# %%
# Adaboost model
# importing module

from sklearn.ensemble import AdaBoostRegressor


# defining model
m2 = AdaBoostRegressor()

# Fitting the model
m2.fit(train1, target)

'''AdaBoostRegressor(base_estimator=None, learning_rate=1.0, loss='linear',
                  n_estimators=50, random_state=None)'''

m2.score(train1, target)*100

# predicting the model with other values (testing the data)
# so AQI is around 46.96
m2.predict([[1, 45, 67, 34, 5, 23]])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
# array([46.96418199])
